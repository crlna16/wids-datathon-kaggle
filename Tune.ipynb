# %%
# !pip install optuna
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: optuna in /mnt/lustre01/pf/k/k202141/.local/lib/python3.8/site-packages (2.10.0)
# Requirement already satisfied: PyYAML in /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages (from optuna) (5.3.1)
# Requirement already satisfied: scipy!=1.4.0 in /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages (from optuna) (1.6.0)
# Requirement already satisfied: alembic in /mnt/lustre01/pf/k/k202141/.local/lib/python3.8/site-packages (from optuna) (1.7.5)
# Requirement already satisfied: tqdm in /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages (from optuna) (4.54.1)
# Requirement already satisfied: cliff in /mnt/lustre01/pf/k/k202141/.local/lib/python3.8/site-packages (from optuna) (3.10.0)
# Requirement already satisfied: packaging>=20.0 in /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages (from optuna) (20.8)
# Requirement already satisfied: colorlog in /mnt/lustre01/pf/k/k202141/.local/lib/python3.8/site-packages (from optuna) (6.6.0)
# Requirement already satisfied: cmaes>=0.8.2 in /mnt/lustre01/pf/k/k202141/.local/lib/python3.8/site-packages (from optuna) (0.8.2)
# Requirement already satisfied: numpy in /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages (from optuna) (1.19.2)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages (from optuna) (1.3.22)
# Requirement already satisfied: importlib-resources in /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages (from alembic->optuna) (5.1.3)
# Requirement already satisfied: importlib-metadata in /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages (from alembic->optuna) (3.4.0)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages (from optuna) (1.3.22)
# Requirement already satisfied: Mako in /mnt/lustre01/pf/k/k202141/.local/lib/python3.8/site-packages (from alembic->optuna) (1.1.6)
# Requirement already satisfied: PyYAML in /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages (from optuna) (5.3.1)
# Requirement already satisfied: stevedore>=2.0.1 in /mnt/lustre01/pf/k/k202141/.local/lib/python3.8/site-packages (from cliff->optuna) (3.5.0)
# Requirement already satisfied: PrettyTable>=0.7.2 in /mnt/lustre01/pf/k/k202141/.local/lib/python3.8/site-packages (from cliff->optuna) (3.0.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /mnt/lustre01/pf/k/k202141/.local/lib/python3.8/site-packages (from cliff->optuna) (5.8.0)
# Requirement already satisfied: cmd2>=1.0.0 in /mnt/lustre01/pf/k/k202141/.local/lib/python3.8/site-packages (from cliff->optuna) (2.3.3)
# Requirement already satisfied: autopage>=0.4.0 in /mnt/lustre01/pf/k/k202141/.local/lib/python3.8/site-packages (from cliff->optuna) (0.5.0)
# Requirement already satisfied: pyparsing>=2.1.0 in /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages (from cliff->optuna) (2.4.7)
# Requirement already satisfied: numpy in /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages (from optuna) (1.19.2)
# Requirement already satisfied: pyperclip>=1.6 in /mnt/lustre01/pf/k/k202141/.local/lib/python3.8/site-packages (from cmd2>=1.0.0->cliff->optuna) (1.8.2)
# Requirement already satisfied: attrs>=16.3.0 in /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages (from cmd2>=1.0.0->cliff->optuna) (20.3.0)
# Requirement already satisfied: wcwidth>=0.1.7 in /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages (from cmd2>=1.0.0->cliff->optuna) (0.2.5)
# Requirement already satisfied: zipp>=0.5 in /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages (from importlib-metadata->alembic->optuna) (3.4.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages (from Mako->alembic->optuna) (1.1.1)
# Requirement already satisfied: pyparsing>=2.1.0 in /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages (from cliff->optuna) (2.4.7)
# Requirement already satisfied: wcwidth>=0.1.7 in /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages (from cmd2>=1.0.0->cliff->optuna) (0.2.5)
# Requirement already satisfied: numpy in /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages (from optuna) (1.19.2)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /mnt/lustre01/pf/k/k202141/.local/lib/python3.8/site-packages (from cliff->optuna) (5.8.0)

# %%
import numpy as np
import pandas as pd
import xgboost

# %%
from sklearn.model_selection import LeaveOneGroupOut
from sklearn.metrics import mean_squared_error
logo = LeaveOneGroupOut()

# %%
import optuna

# %%
X = pd.read_csv('./processed_data/X.csv')
y = pd.read_csv('./processed_data/y.csv').values.squeeze()
year_factor = pd.read_csv('./processed_data/year_factor.csv').values.squeeze()

# %%
def objective(trial):

    valid_metrics = []
    
    n_estimators = trial.suggest_int('n_estimators', 10, 1000, log=True)
    max_depth = trial.suggest_int('max_depth', 1, 20)
    max_delta_step = trial.suggest_int('max_delta_step', 0, 2)
    learning_rate = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    gamma = trial.suggest_float('gamma', 0, 100)
    min_child_weight = trial.suggest_float('min_child_weight', 0, 100)
    subsample = trial.suggest_float('subsample', 0, 1)
    colsample_bytree = trial.suggest_float('colsample_bytree', 0, 1)
    colsample_bylevel = trial.suggest_float('colsample_bylevel', 0, 1)
    colsample_bynode = trial.suggest_float('colsample_bynode', 0, 1)
    reg_alpha = trial.suggest_float('reg_alpha', 1e-6, 1, log=True)
    reg_lambda = trial.suggest_float('reg_lambda', 1e-6, 1, log=True)
    scale_pos_weight = trial.suggest_float('scale_pos_weight', 0, 2)

    for train_index, valid_index in logo.split(X, y, year_factor):
        X_train = X.iloc[train_index]
        y_train = y[train_index]
        X_valid = X.iloc[valid_index]
        y_valid = y[valid_index]
        
        #pruning_callback = optuna.integration.XGBoostPruningCallback(trial, "validation_0-rmse")

        rfr = xgboost.XGBRegressor(n_estimators=n_estimators,
                                   max_depth=max_depth,
                                   learning_rate=learning_rate,
                                   gamma=gamma,
                                   min_child_weight=min_child_weight,
                                   max_delta_step=max_delta_step,
                                   subsample=subsample,
                                   colsample_bytree=colsample_bytree,
                                   colsample_bylevel=colsample_bylevel,
                                   colsample_bynode=colsample_bynode,
                                   reg_alpha=reg_alpha,
                                   reg_lambda=reg_lambda,
                                   scale_pos_weight=scale_pos_weight,
                                   random_state=700)
        
        rfr = rfr.fit(X_train, y_train, 
                      eval_set=[(X_valid, y_valid)], 
                      early_stopping_rounds=10, 
                      callbacks=[],
                      verbose=0)
    
        #print('*'*40)
        #print('Evaluating on year_factor', pd.Series(year_factor[valid_index]).unique())
        #print(f'Train: {len(y_train)}, Valid: {len(y_valid)}')
        #print('R2:   ', rfr.score(X_valid, y_valid))
    
        y_valid_hat = rfr.predict(X_valid)
    #if transform_labels:
    #    y_valid = qtrafo.inverse_transform(y_valid.reshape(-1, 1)).squeeze()
    #    y_valid_hat = qtrafo.inverse_transform(y_valid_hat.reshape(-1, 1)).squeeze() 
        score = rfr.score(X_valid, y_valid)
        rmse = mean_squared_error(y_valid, y_valid_hat, squared=False)
        #print('RMSE: ', rmse)
    
        valid_metrics.append(score)
        
    return np.mean(valid_metrics)

# %%
study = optuna.create_study(direction='maximize') #pruner=optuna.pruners.MedianPruner(n_warmup_steps=5)
# Out:
# [I 2022-01-25 15:48:50,226] A new study created in memory with name: no-name-e3b500a6-b539-4782-8b81-24c26077bb09

# %%
study.optimize(objective, n_trials=100, timeout=5400)
# Out:
# [I 2022-01-25 15:48:54,560] Trial 0 finished with value: -1.530671365567067 and parameters: {'n_estimators': 20, 'max_depth': 15, 'max_delta_step': 0, 'learning_rate': 0.006788983980943314, 'gamma': 31.060515621671225, 'min_child_weight': 45.49909425604896, 'subsample': 0.24004085871430125, 'colsample_bytree': 0.03811800292752776, 'colsample_bylevel': 0.82394372595653, 'colsample_bynode': 0.4397186368296735, 'reg_alpha': 1.4339047662415767e-05, 'reg_lambda': 2.6102692864246574e-06, 'scale_pos_weight': 0.3712054393670601}. Best is trial 0 with value: -1.530671365567067.
# [I 2022-01-25 15:48:55,850] Trial 1 finished with value: -2.0031623500066873 and parameters: {'n_estimators': 25, 'max_depth': 7, 'max_delta_step': 2, 'learning_rate': 0.00016156473184367236, 'gamma': 14.456204463106836, 'min_child_weight': 88.01426633907226, 'subsample': 0.6593477819926805, 'colsample_bytree': 0.10517179028428969, 'colsample_bylevel': 0.6614908766382505, 'colsample_bynode': 0.3124451967369345, 'reg_alpha': 0.26955753016431894, 'reg_lambda': 0.0005223944601913586, 'scale_pos_weight': 0.2869981459574975}. Best is trial 0 with value: -1.530671365567067.
# [I 2022-01-25 15:48:57,448] Trial 2 finished with value: -2.002275186738785 and parameters: {'n_estimators': 43, 'max_depth': 7, 'max_delta_step': 2, 'learning_rate': 0.00030735995491979634, 'gamma': 64.9826722485403, 'min_child_weight': 76.23748970430101, 'subsample': 0.9086429227986285, 'colsample_bytree': 0.25740652937216635, 'colsample_bylevel': 0.5386321650368346, 'colsample_bynode': 0.8740072541163286, 'reg_alpha': 0.0005146294047936145, 'reg_lambda': 0.1473483653734314, 'scale_pos_weight': 1.8201133401563916}. Best is trial 0 with value: -1.530671365567067.
# [I 2022-01-25 15:49:00,528] Trial 3 finished with value: -0.9345340625938938 and parameters: {'n_estimators': 44, 'max_depth': 13, 'max_delta_step': 0, 'learning_rate': 0.008929965109615155, 'gamma': 47.57082893849801, 'min_child_weight': 3.194931712000759, 'subsample': 0.4363606790649609, 'colsample_bytree': 0.6186309325430234, 'colsample_bylevel': 0.2676571003324738, 'colsample_bynode': 0.00406554297017947, 'reg_alpha': 0.0012077977123113425, 'reg_lambda': 0.2714233000647818, 'scale_pos_weight': 0.7116088906707205}. Best is trial 3 with value: -0.9345340625938938.
# [I 2022-01-25 15:49:08,925] Trial 4 finished with value: -1.8076149736223115 and parameters: {'n_estimators': 299, 'max_depth': 20, 'max_delta_step': 2, 'learning_rate': 0.006951928989134574, 'gamma': 47.555216563096515, 'min_child_weight': 7.699137304585579, 'subsample': 0.3677530741244025, 'colsample_bytree': 0.7506718720459584, 'colsample_bylevel': 0.4982000104940164, 'colsample_bynode': 0.5522236636721699, 'reg_alpha': 0.19208044325847146, 'reg_lambda': 0.012613063386781361, 'scale_pos_weight': 0.7091431967508048}. Best is trial 3 with value: -0.9345340625938938.
# [I 2022-01-25 15:49:12,656] Trial 5 finished with value: -1.967342037387543 and parameters: {'n_estimators': 86, 'max_depth': 17, 'max_delta_step': 0, 'learning_rate': 0.00010365525152445375, 'gamma': 35.677142253294555, 'min_child_weight': 58.77078382748682, 'subsample': 0.006358184564148384, 'colsample_bytree': 0.7084524633795787, 'colsample_bylevel': 0.8882294705612308, 'colsample_bynode': 0.9408806714169242, 'reg_alpha': 1.9326697307544715e-05, 'reg_lambda': 0.00010350768294812058, 'scale_pos_weight': 0.2293398885580642}. Best is trial 3 with value: -0.9345340625938938.
# [I 2022-01-25 15:49:13,737] Trial 6 finished with value: -1.8745035539753871 and parameters: {'n_estimators': 12, 'max_depth': 11, 'max_delta_step': 0, 'learning_rate': 0.002779535339667442, 'gamma': 40.30020720810866, 'min_child_weight': 48.17129640057159, 'subsample': 0.011451884978185833, 'colsample_bytree': 0.3537669741310636, 'colsample_bylevel': 0.8122591495562941, 'colsample_bynode': 0.5554871123589882, 'reg_alpha': 3.927593326327267e-06, 'reg_lambda': 0.00630589169852638, 'scale_pos_weight': 1.0511321222742747}. Best is trial 3 with value: -0.9345340625938938.
# [I 2022-01-25 15:49:34,911] Trial 7 finished with value: -1.6661910798577488 and parameters: {'n_estimators': 415, 'max_depth': 18, 'max_delta_step': 0, 'learning_rate': 0.00022537280996783013, 'gamma': 28.441194706826888, 'min_child_weight': 83.61242263580006, 'subsample': 0.8242088305874568, 'colsample_bytree': 0.6276019928272571, 'colsample_bylevel': 0.43451905074532693, 'colsample_bynode': 0.10558258819735855, 'reg_alpha': 1.6797692788573074e-06, 'reg_lambda': 0.007673074346253037, 'scale_pos_weight': 0.6337806221076816}. Best is trial 3 with value: -0.9345340625938938.
# [I 2022-01-25 15:49:35,951] Trial 8 finished with value: -1.9944161010296113 and parameters: {'n_estimators': 11, 'max_depth': 7, 'max_delta_step': 0, 'learning_rate': 0.00020965447405977273, 'gamma': 77.31498527626134, 'min_child_weight': 88.33066796375296, 'subsample': 0.3692318709443918, 'colsample_bytree': 0.06985575281021006, 'colsample_bylevel': 0.20872647908349995, 'colsample_bynode': 0.1599344440391417, 'reg_alpha': 0.02662938962222208, 'reg_lambda': 0.0011279248626287607, 'scale_pos_weight': 0.1143904136371614}. Best is trial 3 with value: -0.9345340625938938.
# [I 2022-01-25 15:49:55,074] Trial 9 finished with value: -0.54752822433709 and parameters: {'n_estimators': 454, 'max_depth': 10, 'max_delta_step': 0, 'learning_rate': 0.0015011364473703946, 'gamma': 28.1608752309769, 'min_child_weight': 46.4289315601644, 'subsample': 0.35831717011001774, 'colsample_bytree': 0.005623427244284107, 'colsample_bylevel': 0.29907520958949674, 'colsample_bynode': 0.3271551243097067, 'reg_alpha': 0.37298169135571385, 'reg_lambda': 0.19557956247667496, 'scale_pos_weight': 0.6262567002721482}. Best is trial 9 with value: -0.54752822433709.
# [I 2022-01-25 15:50:16,995] Trial 10 finished with value: -1.9622938782824586 and parameters: {'n_estimators': 901, 'max_depth': 2, 'max_delta_step': 1, 'learning_rate': 0.000952107148465028, 'gamma': 97.9790377330769, 'min_child_weight': 27.051798887541093, 'subsample': 0.6211792142762995, 'colsample_bytree': 0.8878087658419036, 'colsample_bylevel': 0.004587361230277365, 'colsample_bynode': 0.7461784228296848, 'reg_alpha': 0.006761939824013814, 'reg_lambda': 0.9675365080510485, 'scale_pos_weight': 1.3827398994561007}. Best is trial 9 with value: -0.54752822433709.
# [I 2022-01-25 15:50:20,789] Trial 11 finished with value: -1.9926622521746686 and parameters: {'n_estimators': 143, 'max_depth': 12, 'max_delta_step': 1, 'learning_rate': 0.0015774194787832063, 'gamma': 4.423791757600995, 'min_child_weight': 0.8514054780713991, 'subsample': 0.5018913498754933, 'colsample_bytree': 0.47200512209457535, 'colsample_bylevel': 0.2277806633345335, 'colsample_bynode': 0.019364425979349224, 'reg_alpha': 0.0006505887258378922, 'reg_lambda': 0.17850034141016757, 'scale_pos_weight': 0.9958157039365565}. Best is trial 9 with value: -0.54752822433709.
# [I 2022-01-25 15:50:23,133] Trial 12 finished with value: -2.0010569926012365 and parameters: {'n_estimators': 85, 'max_depth': 14, 'max_delta_step': 1, 'learning_rate': 0.0006075689172841212, 'gamma': 63.64720633333555, 'min_child_weight': 24.953649203668725, 'subsample': 0.24605779773454306, 'colsample_bytree': 0.5334243586448767, 'colsample_bylevel': 0.2976569682148876, 'colsample_bynode': 0.2712175494583495, 'reg_alpha': 0.9568042790484095, 'reg_lambda': 0.934384380193826, 'scale_pos_weight': 0.7188454521129316}. Best is trial 9 with value: -0.54752822433709.
# [I 2022-01-25 15:50:34,643] Trial 13 finished with value: -0.5060141229788446 and parameters: {'n_estimators': 215, 'max_depth': 10, 'max_delta_step': 0, 'learning_rate': 0.0032381481432672754, 'gamma': 18.18774911674882, 'min_child_weight': 24.667217299303402, 'subsample': 0.4733846713493761, 'colsample_bytree': 0.9223446632645418, 'colsample_bylevel': 0.0457501282013458, 'colsample_bynode': 0.3445320728928641, 'reg_alpha': 0.006784521899083932, 'reg_lambda': 0.1280647464795759, 'scale_pos_weight': 1.124957943987977}. Best is trial 13 with value: -0.5060141229788446.
# [I 2022-01-25 15:50:40,675] Trial 14 finished with value: -1.963429422497498 and parameters: {'n_estimators': 274, 'max_depth': 9, 'max_delta_step': 1, 'learning_rate': 0.003044303032535087, 'gamma': 15.520329401358127, 'min_child_weight': 31.843636901233715, 'subsample': 0.21696726499224894, 'colsample_bytree': 0.9027906299299093, 'colsample_bylevel': 0.029002299969743905, 'colsample_bynode': 0.4059224676999503, 'reg_alpha': 0.02621739677299798, 'reg_lambda': 0.03574215304265337, 'scale_pos_weight': 1.3943915724310028}. Best is trial 13 with value: -0.5060141229788446.
# [I 2022-01-25 15:51:06,115] Trial 15 finished with value: 0.034457713985771334 and parameters: {'n_estimators': 837, 'max_depth': 3, 'max_delta_step': 0, 'learning_rate': 0.003277530441049148, 'gamma': 17.877424841687404, 'min_child_weight': 62.60438659593392, 'subsample': 0.5970580929364957, 'colsample_bytree': 0.2600582993996935, 'colsample_bylevel': 0.12319665925247116, 'colsample_bynode': 0.7286236816010963, 'reg_alpha': 0.0056367653015011445, 'reg_lambda': 0.050240594059130846, 'scale_pos_weight': 1.1472477647315404}. Best is trial 15 with value: 0.034457713985771334.
# [I 2022-01-25 15:51:22,242] Trial 16 finished with value: -1.8744497381179972 and parameters: {'n_estimators': 752, 'max_depth': 1, 'max_delta_step': 1, 'learning_rate': 0.003610263114032105, 'gamma': 2.96963264701356, 'min_child_weight': 65.44189514447936, 'subsample': 0.7027463208107362, 'colsample_bytree': 0.2555427472814682, 'colsample_bylevel': 0.09969019371581982, 'colsample_bynode': 0.7342304505800568, 'reg_alpha': 0.00395383269372126, 'reg_lambda': 0.03542341465202055, 'scale_pos_weight': 1.3406732840402606}. Best is trial 15 with value: 0.034457713985771334.
# [I 2022-01-25 15:51:29,115] Trial 17 finished with value: -0.402468014099052 and parameters: {'n_estimators': 151, 'max_depth': 4, 'max_delta_step': 0, 'learning_rate': 0.004794006632934188, 'gamma': 17.445802118070517, 'min_child_weight': 16.950286246597685, 'subsample': 0.5547705690286301, 'colsample_bytree': 0.9657423601863615, 'colsample_bylevel': 0.17981213270332078, 'colsample_bynode': 0.6795562168393857, 'reg_alpha': 0.0001457466111211127, 'reg_lambda': 2.970601972493e-05, 'scale_pos_weight': 1.7666248670654783}. Best is trial 15 with value: 0.034457713985771334.
# [I 2022-01-25 15:51:50,626] Trial 18 finished with value: 0.07987255607259554 and parameters: {'n_estimators': 613, 'max_depth': 4, 'max_delta_step': 0, 'learning_rate': 0.004900325010676915, 'gamma': 20.528603378785483, 'min_child_weight': 68.36463124612618, 'subsample': 0.786550682371504, 'colsample_bytree': 0.36565832968129747, 'colsample_bylevel': 0.16664468595359172, 'colsample_bynode': 0.7089178220997694, 'reg_alpha': 0.00010590518041982784, 'reg_lambda': 9.83714482196299e-06, 'scale_pos_weight': 1.9889761091497178}. Best is trial 18 with value: 0.07987255607259554.
# [I 2022-01-25 15:52:04,186] Trial 19 finished with value: -1.950242449308569 and parameters: {'n_estimators': 570, 'max_depth': 4, 'max_delta_step': 1, 'learning_rate': 0.001947608659480625, 'gamma': 56.7627297278983, 'min_child_weight': 70.1445320154089, 'subsample': 0.9848087432705038, 'colsample_bytree': 0.3211765672248992, 'colsample_bylevel': 0.3662204901921453, 'colsample_bynode': 0.8486225656018308, 'reg_alpha': 5.6960702318276706e-05, 'reg_lambda': 1.2711138177765003e-06, 'scale_pos_weight': 1.9534761969641197}. Best is trial 18 with value: 0.07987255607259554.
# [I 2022-01-25 15:52:32,798] Trial 20 finished with value: -0.46955035232635894 and parameters: {'n_estimators': 889, 'max_depth': 4, 'max_delta_step': 0, 'learning_rate': 0.0008185555017036328, 'gamma': 0.5529138457736522, 'min_child_weight': 58.11657124503296, 'subsample': 0.7786765477152916, 'colsample_bytree': 0.43513105523498996, 'colsample_bylevel': 0.14687852743116647, 'colsample_bynode': 0.6464247798039316, 'reg_alpha': 8.998283432804011e-05, 'reg_lambda': 2.0145838542343287e-05, 'scale_pos_weight': 1.612551051211927}. Best is trial 18 with value: 0.07987255607259554.
# [I 2022-01-25 15:52:38,853] Trial 21 finished with value: -0.45950145823811167 and parameters: {'n_estimators': 154, 'max_depth': 4, 'max_delta_step': 0, 'learning_rate': 0.00482305120550927, 'gamma': 22.888781091418377, 'min_child_weight': 36.53711435699452, 'subsample': 0.577831248489512, 'colsample_bytree': 0.17474491279441795, 'colsample_bylevel': 0.15068356142972905, 'colsample_bynode': 0.6847488828262167, 'reg_alpha': 0.00012172160522627412, 'reg_lambda': 1.3255431466065773e-05, 'scale_pos_weight': 1.714887684117572}. Best is trial 18 with value: 0.07987255607259554.
# [I 2022-01-25 15:52:58,801] Trial 22 finished with value: 0.08512418562862198 and parameters: {'n_estimators': 524, 'max_depth': 3, 'max_delta_step': 0, 'learning_rate': 0.004864403838865833, 'gamma': 10.918838324190425, 'min_child_weight': 99.34883155609873, 'subsample': 0.7814195454330936, 'colsample_bytree': 0.38476226453376455, 'colsample_bylevel': 0.37215751682646814, 'colsample_bynode': 0.614815188626279, 'reg_alpha': 0.0004215871017884889, 'reg_lambda': 4.062277014477044e-05, 'scale_pos_weight': 1.581451599633702}. Best is trial 22 with value: 0.08512418562862198.
# [I 2022-01-25 15:53:32,777] Trial 23 finished with value: 0.08066931166262545 and parameters: {'n_estimators': 560, 'max_depth': 2, 'max_delta_step': 0, 'learning_rate': 0.00500741440983642, 'gamma': 11.128971399565874, 'min_child_weight': 99.15244722105733, 'subsample': 0.7562589833056906, 'colsample_bytree': 0.3850589360787201, 'colsample_bylevel': 0.36140611626344993, 'colsample_bynode': 0.8034970226484488, 'reg_alpha': 0.0014942861149046386, 'reg_lambda': 0.00023163274491607276, 'scale_pos_weight': 1.9815985669510168}. Best is trial 22 with value: 0.08512418562862198.
# [I 2022-01-25 15:53:51,047] Trial 24 finished with value: 0.1192467078469873 and parameters: {'n_estimators': 499, 'max_depth': 1, 'max_delta_step': 0, 'learning_rate': 0.009889789582200801, 'gamma': 9.00619779222976, 'min_child_weight': 97.9334604771664, 'subsample': 0.7647042306460278, 'colsample_bytree': 0.39181729107942415, 'colsample_bylevel': 0.6269111129376537, 'colsample_bynode': 0.8536050463646534, 'reg_alpha': 0.0003130103880526944, 'reg_lambda': 0.0001412827882425942, 'scale_pos_weight': 1.9860836313197483}. Best is trial 24 with value: 0.1192467078469873.
# [I 2022-01-25 15:53:59,771] Trial 25 finished with value: -1.8449799790738592 and parameters: {'n_estimators': 350, 'max_depth': 1, 'max_delta_step': 1, 'learning_rate': 0.009564761736127716, 'gamma': 8.145018573455737, 'min_child_weight': 99.69179119547852, 'subsample': 0.8685510068288544, 'colsample_bytree': 0.5562810496522844, 'colsample_bylevel': 0.6126700901408008, 'colsample_bynode': 0.9751381639010201, 'reg_alpha': 0.0013822002983519244, 'reg_lambda': 0.00018016820779622047, 'scale_pos_weight': 1.5484430056915326}. Best is trial 24 with value: 0.1192467078469873.
# [I 2022-01-25 15:54:34,578] Trial 26 finished with value: 0.238152588526155 and parameters: {'n_estimators': 527, 'max_depth': 6, 'max_delta_step': 0, 'learning_rate': 0.006431281136464536, 'gamma': 9.012418261911002, 'min_child_weight': 99.68717200826899, 'subsample': 0.7245538541924885, 'colsample_bytree': 0.44453238501279024, 'colsample_bylevel': 0.697955150320956, 'colsample_bynode': 0.8354451809641317, 'reg_alpha': 0.00025671910868091223, 'reg_lambda': 0.0011588311315603192, 'scale_pos_weight': 1.8653059057303214}. Best is trial 26 with value: 0.238152588526155.
# [I 2022-01-25 15:55:00,184] Trial 27 finished with value: 0.07452806999989223 and parameters: {'n_estimators': 219, 'max_depth': 6, 'max_delta_step': 0, 'learning_rate': 0.007131860681060571, 'gamma': 0.08979072281178979, 'min_child_weight': 93.56772915246604, 'subsample': 0.9837862697012738, 'colsample_bytree': 0.43937358505569996, 'colsample_bylevel': 0.704180548857363, 'colsample_bynode': 0.6091544393630471, 'reg_alpha': 0.00033141175319606757, 'reg_lambda': 0.0013683129944217175, 'scale_pos_weight': 1.597641643567896}. Best is trial 26 with value: 0.238152588526155.
# [I 2022-01-25 15:55:11,310] Trial 28 finished with value: -1.816883875096582 and parameters: {'n_estimators': 406, 'max_depth': 5, 'max_delta_step': 1, 'learning_rate': 0.009743024922363046, 'gamma': 40.286213547275864, 'min_child_weight': 78.70146760588217, 'subsample': 0.725093572917482, 'colsample_bytree': 0.14609068001342856, 'colsample_bylevel': 0.9697064019122572, 'colsample_bynode': 0.9091243509176978, 'reg_alpha': 2.475540495081853e-05, 'reg_lambda': 6.0940561759036325e-05, 'scale_pos_weight': 1.8161729647649592}. Best is trial 26 with value: 0.238152588526155.
# [I 2022-01-25 15:55:16,878] Trial 29 finished with value: -1.4984442994053504 and parameters: {'n_estimators': 59, 'max_depth': 8, 'max_delta_step': 0, 'learning_rate': 0.0022960271688836505, 'gamma': 9.87155274994457, 'min_child_weight': 89.1750617021566, 'subsample': 0.9157173296102286, 'colsample_bytree': 0.5106287541111795, 'colsample_bylevel': 0.7640129417308887, 'colsample_bynode': 0.8077103529753558, 'reg_alpha': 6.803455183796425e-06, 'reg_lambda': 5.062954836629583e-06, 'scale_pos_weight': 1.4635437341870503}. Best is trial 26 with value: 0.238152588526155.
# [I 2022-01-25 15:55:23,030] Trial 30 finished with value: -0.10106887996126437 and parameters: {'n_estimators': 196, 'max_depth': 2, 'max_delta_step': 0, 'learning_rate': 0.006310873993972902, 'gamma': 25.61608457448882, 'min_child_weight': 94.76867500694591, 'subsample': 0.8489805256618121, 'colsample_bytree': 0.6192669048098071, 'colsample_bylevel': 0.5827161070902845, 'colsample_bynode': 0.44893373307146733, 'reg_alpha': 0.0003049317283955686, 'reg_lambda': 0.0005420679006894639, 'scale_pos_weight': 1.239275820690847}. Best is trial 26 with value: 0.238152588526155.
# [I 2022-01-25 15:55:49,253] Trial 31 finished with value: 0.11114270815747333 and parameters: {'n_estimators': 562, 'max_depth': 2, 'max_delta_step': 0, 'learning_rate': 0.005077724293216451, 'gamma': 11.009938795988715, 'min_child_weight': 97.75892247959501, 'subsample': 0.7199875239286353, 'colsample_bytree': 0.4225636904444809, 'colsample_bylevel': 0.4258949593359307, 'colsample_bynode': 0.8008620879213958, 'reg_alpha': 0.0020093266989562922, 'reg_lambda': 0.00026663295286470017, 'scale_pos_weight': 1.9122569052719267}. Best is trial 26 with value: 0.238152588526155.
# [I 2022-01-25 15:56:08,449] Trial 32 finished with value: 0.0682139424665815 and parameters: {'n_estimators': 542, 'max_depth': 1, 'max_delta_step': 0, 'learning_rate': 0.006279696003586624, 'gamma': 9.402459012647235, 'min_child_weight': 78.82263917895843, 'subsample': 0.6742664583119383, 'colsample_bytree': 0.31189122321428864, 'colsample_bylevel': 0.425271203638529, 'colsample_bynode': 0.9984757169038005, 'reg_alpha': 0.002804284440935473, 'reg_lambda': 0.0036536287216259616, 'scale_pos_weight': 1.8729307727265092}. Best is trial 26 with value: 0.238152588526155.
# [I 2022-01-25 15:56:27,950] Trial 33 finished with value: -0.0051796960302780805 and parameters: {'n_estimators': 317, 'max_depth': 6, 'max_delta_step': 0, 'learning_rate': 0.004059859861909225, 'gamma': 11.89674588500321, 'min_child_weight': 93.94948666928936, 'subsample': 0.6607287398939732, 'colsample_bytree': 0.4281561744369875, 'colsample_bylevel': 0.7007310152742223, 'colsample_bynode': 0.8080057583839415, 'reg_alpha': 0.024037543022334386, 'reg_lambda': 0.00032168113943627875, 'scale_pos_weight': 1.6916714508640212}. Best is trial 26 with value: 0.238152588526155.
# [I 2022-01-25 15:56:45,226] Trial 34 finished with value: -1.5328302299856253 and parameters: {'n_estimators': 686, 'max_depth': 3, 'max_delta_step': 2, 'learning_rate': 0.007571834766121386, 'gamma': 32.30241264877198, 'min_child_weight': 85.7444097552399, 'subsample': 0.7364775284281807, 'colsample_bytree': 0.21527404665400407, 'colsample_bylevel': 0.4869087473813012, 'colsample_bynode': 0.8957911043675768, 'reg_alpha': 4.412065686431464e-05, 'reg_lambda': 5.042893444134296e-05, 'scale_pos_weight': 1.8610242891087383}. Best is trial 26 with value: 0.238152588526155.
# [I 2022-01-25 15:56:47,104] Trial 35 finished with value: -1.515123921945603 and parameters: {'n_estimators': 23, 'max_depth': 6, 'max_delta_step': 0, 'learning_rate': 0.005844487676555489, 'gamma': 6.755253926218883, 'min_child_weight': 82.26585804349122, 'subsample': 0.9362786426827381, 'colsample_bytree': 0.4854208616629908, 'colsample_bylevel': 0.5672886327868072, 'colsample_bynode': 0.590951274559736, 'reg_alpha': 0.0002824599599424909, 'reg_lambda': 0.0022998912694399036, 'scale_pos_weight': 1.7125486298323382}. Best is trial 26 with value: 0.238152588526155.
# [I 2022-01-25 15:57:16,684] Trial 36 finished with value: 0.22877905847707308 and parameters: {'n_estimators': 978, 'max_depth': 3, 'max_delta_step': 0, 'learning_rate': 0.009987773866599207, 'gamma': 77.79679668195413, 'min_child_weight': 73.42230487163089, 'subsample': 0.8192492215239059, 'colsample_bytree': 0.5854244220914093, 'colsample_bylevel': 0.644316984299331, 'colsample_bynode': 0.5030679136874232, 'reg_alpha': 0.0006145741984085103, 'reg_lambda': 0.00046926154134962496, 'scale_pos_weight': 1.8702659515802906}. Best is trial 26 with value: 0.238152588526155.
# [I 2022-01-25 15:58:15,357] Trial 37 finished with value: -0.7856653039566535 and parameters: {'n_estimators': 972, 'max_depth': 5, 'max_delta_step': 0, 'learning_rate': 0.0004272166477015498, 'gamma': 80.54153389436838, 'min_child_weight': 75.4087746051436, 'subsample': 0.8638103320402231, 'colsample_bytree': 0.7042366042360296, 'colsample_bylevel': 0.6603325762908033, 'colsample_bynode': 0.8520006224018083, 'reg_alpha': 0.001076341783977228, 'reg_lambda': 0.0006919964215451452, 'scale_pos_weight': 1.9063097964471312}. Best is trial 26 with value: 0.238152588526155.
# [I 2022-01-25 15:58:51,138] Trial 38 finished with value: -1.3924970187990775 and parameters: {'n_estimators': 701, 'max_depth': 8, 'max_delta_step': 2, 'learning_rate': 0.009834288955213892, 'gamma': 81.24939779145065, 'min_child_weight': 73.93821734381729, 'subsample': 0.6388263571959051, 'colsample_bytree': 0.5714608602132414, 'colsample_bylevel': 0.787713225747661, 'colsample_bynode': 0.47763836206810806, 'reg_alpha': 0.0016943571433791925, 'reg_lambda': 0.00010834494417074765, 'scale_pos_weight': 1.7960814791089201}. Best is trial 26 with value: 0.238152588526155.
# [I 2022-01-25 15:58:59,457] Trial 39 finished with value: 0.07160997188029417 and parameters: {'n_estimators': 268, 'max_depth': 2, 'max_delta_step': 0, 'learning_rate': 0.007807814580384617, 'gamma': 99.46661920372134, 'min_child_weight': 91.66281058171643, 'subsample': 0.8158146842779659, 'colsample_bytree': 0.694866610063251, 'colsample_bylevel': 0.5280817092538191, 'colsample_bynode': 0.5204990905344065, 'reg_alpha': 0.07941745642604559, 'reg_lambda': 0.0003560962146680126, 'scale_pos_weight': 1.662708105726339}. Best is trial 26 with value: 0.238152588526155.
# [I 2022-01-25 15:59:12,836] Trial 40 finished with value: -0.19804026446510353 and parameters: {'n_estimators': 417, 'max_depth': 1, 'max_delta_step': 0, 'learning_rate': 0.002409606393464912, 'gamma': 70.89092476729289, 'min_child_weight': 53.03690452182398, 'subsample': 0.6981910532046239, 'colsample_bytree': 0.7584534411229762, 'colsample_bylevel': 0.870051819745215, 'colsample_bynode': 0.9417305410079695, 'reg_alpha': 0.012766875385138522, 'reg_lambda': 0.00210098625167997, 'scale_pos_weight': 1.5142205825927877}. Best is trial 26 with value: 0.238152588526155.
# [I 2022-01-25 15:59:44,771] Trial 41 finished with value: 0.17343217223563206 and parameters: {'n_estimators': 506, 'max_depth': 3, 'max_delta_step': 0, 'learning_rate': 0.00803443238992872, 'gamma': 91.69660685674995, 'min_child_weight': 98.59848479795072, 'subsample': 0.7832971494557927, 'colsample_bytree': 0.39103859913009115, 'colsample_bylevel': 0.45835980654362374, 'colsample_bynode': 0.7733915250216058, 'reg_alpha': 0.0006562905558345182, 'reg_lambda': 0.00013953648079957282, 'scale_pos_weight': 1.8721296922790462}. Best is trial 26 with value: 0.238152588526155.
# [I 2022-01-25 15:59:57,778] Trial 42 finished with value: 0.16396813069045807 and parameters: {'n_estimators': 360, 'max_depth': 3, 'max_delta_step': 0, 'learning_rate': 0.008149843599577353, 'gamma': 93.73347361289758, 'min_child_weight': 85.65455685584553, 'subsample': 0.9322679562784415, 'colsample_bytree': 0.4153025207751294, 'colsample_bylevel': 0.632351340288069, 'colsample_bynode': 0.777472531011954, 'reg_alpha': 0.0002258904162569372, 'reg_lambda': 0.00011528843744151456, 'scale_pos_weight': 1.881311862052184}. Best is trial 26 with value: 0.238152588526155.
# [I 2022-01-25 16:00:19,790] Trial 43 finished with value: 0.2340447484986421 and parameters: {'n_estimators': 387, 'max_depth': 5, 'max_delta_step': 0, 'learning_rate': 0.007910016183302558, 'gamma': 89.22602265076792, 'min_child_weight': 85.7099861984048, 'subsample': 0.8645344159028315, 'colsample_bytree': 0.5769787850638985, 'colsample_bylevel': 0.6325588293625903, 'colsample_bynode': 0.8690356858073452, 'reg_alpha': 0.0005953744678987399, 'reg_lambda': 0.00010389980467388745, 'scale_pos_weight': 1.7854301662615972}. Best is trial 26 with value: 0.238152588526155.
# [I 2022-01-25 16:01:03,295] Trial 44 finished with value: 0.21485266600406616 and parameters: {'n_estimators': 351, 'max_depth': 5, 'max_delta_step': 0, 'learning_rate': 0.00721123523242198, 'gamma': 89.38965592329943, 'min_child_weight': 85.02198862011217, 'subsample': 0.9373095297343248, 'colsample_bytree': 0.5858436766525094, 'colsample_bylevel': 0.7390653735819506, 'colsample_bynode': 0.7672780002491231, 'reg_alpha': 0.0006860583926491027, 'reg_lambda': 9.142993465979227e-05, 'scale_pos_weight': 1.8261420302230806}. Best is trial 26 with value: 0.238152588526155.
# [I 2022-01-25 16:01:25,041] Trial 45 finished with value: -0.6904380588367646 and parameters: {'n_estimators': 120, 'max_depth': 7, 'max_delta_step': 0, 'learning_rate': 0.003877922727770473, 'gamma': 89.0541841002115, 'min_child_weight': 81.54788566886691, 'subsample': 0.8918057185744575, 'colsample_bytree': 0.660055525305749, 'colsample_bylevel': 0.7296525059824888, 'colsample_bynode': 0.9448879983991537, 'reg_alpha': 0.0007424623128696094, 'reg_lambda': 0.0008548334116325904, 'scale_pos_weight': 1.7845663806212886}. Best is trial 26 with value: 0.238152588526155.
# [I 2022-01-25 16:01:44,022] Trial 46 finished with value: 0.10063547934549935 and parameters: {'n_estimators': 260, 'max_depth': 5, 'max_delta_step': 0, 'learning_rate': 0.006589356230376363, 'gamma': 92.55577435999923, 'min_child_weight': 90.17114136563244, 'subsample': 0.8284720172486169, 'colsample_bytree': 0.7842474508681395, 'colsample_bylevel': 0.8694019059147531, 'colsample_bynode': 0.244168956753274, 'reg_alpha': 0.0006311035732152824, 'reg_lambda': 7.33092368910694e-05, 'scale_pos_weight': 0.8199132958000028}. Best is trial 26 with value: 0.238152588526155.
# [I 2022-01-25 16:01:46,690] Trial 47 finished with value: -1.1455388999222411 and parameters: {'n_estimators': 33, 'max_depth': 8, 'max_delta_step': 0, 'learning_rate': 0.008113748321444519, 'gamma': 86.58189788084553, 'min_child_weight': 72.36070296580772, 'subsample': 0.9633101917633676, 'colsample_bytree': 0.5711073189554824, 'colsample_bylevel': 0.4765397515714996, 'colsample_bynode': 0.3800945310122365, 'reg_alpha': 3.8057582783505405e-05, 'reg_lambda': 0.00969768669298184, 'scale_pos_weight': 1.4921737777716186}. Best is trial 26 with value: 0.238152588526155.
# [I 2022-01-25 16:01:47,735] Trial 48 finished with value: -1.9992486154768723 and parameters: {'n_estimators': 15, 'max_depth': 16, 'max_delta_step': 1, 'learning_rate': 0.005938590759921333, 'gamma': 70.13933536953805, 'min_child_weight': 86.99417880582446, 'subsample': 0.8903950156195408, 'colsample_bytree': 0.6054870314089237, 'colsample_bylevel': 0.7518128963184784, 'colsample_bynode': 0.7526795128910291, 'reg_alpha': 0.0008207009551900173, 'reg_lambda': 0.0012326753093546627, 'scale_pos_weight': 0.48333948719450726}. Best is trial 26 with value: 0.238152588526155.
# [I 2022-01-25 16:02:34,221] Trial 49 finished with value: 0.27068612029500494 and parameters: {'n_estimators': 764, 'max_depth': 6, 'max_delta_step': 0, 'learning_rate': 0.007802891466915495, 'gamma': 86.5843552676085, 'min_child_weight': 80.56579598040926, 'subsample': 0.814039750998124, 'colsample_bytree': 0.5097219772140784, 'colsample_bylevel': 0.6970069427084373, 'colsample_bynode': 0.8884595730147044, 'reg_alpha': 0.00017303974556927415, 'reg_lambda': 0.005700083795837294, 'scale_pos_weight': 1.66045029951116}. Best is trial 49 with value: 0.27068612029500494.
# [I 2022-01-25 16:03:05,621] Trial 50 finished with value: -1.9964970426154207 and parameters: {'n_estimators': 993, 'max_depth': 9, 'max_delta_step': 1, 'learning_rate': 0.00014709076905167453, 'gamma': 83.90661761507157, 'min_child_weight': 78.6971407858692, 'subsample': 0.8231696031025881, 'colsample_bytree': 0.6580119593794613, 'colsample_bylevel': 0.837669110006779, 'colsample_bynode': 0.897826171833067, 'reg_alpha': 9.553172649805722e-06, 'reg_lambda': 0.004856011004313582, 'scale_pos_weight': 1.6537857052891285}. Best is trial 49 with value: 0.27068612029500494.
# [I 2022-01-25 16:03:56,685] Trial 51 finished with value: 0.25839469183553404 and parameters: {'n_estimators': 736, 'max_depth': 5, 'max_delta_step': 0, 'learning_rate': 0.007493815220555734, 'gamma': 74.89885460898728, 'min_child_weight': 82.96608862847147, 'subsample': 0.9424826926990818, 'colsample_bytree': 0.5072151096808446, 'colsample_bylevel': 0.6837869082444971, 'colsample_bynode': 0.8430196574757155, 'reg_alpha': 0.00018711896375387516, 'reg_lambda': 0.00048598569486009636, 'scale_pos_weight': 1.7645921385859726}. Best is trial 49 with value: 0.27068612029500494.
# [I 2022-01-25 16:05:27,843] Trial 52 finished with value: 0.23778532871732122 and parameters: {'n_estimators': 784, 'max_depth': 6, 'max_delta_step': 0, 'learning_rate': 0.003873518674321005, 'gamma': 72.87971579420224, 'min_child_weight': 81.64976138490326, 'subsample': 0.9988127669198916, 'colsample_bytree': 0.49779808621600247, 'colsample_bylevel': 0.6787151819585896, 'colsample_bynode': 0.8685233179267966, 'reg_alpha': 0.00018892111190097274, 'reg_lambda': 0.01421734542835474, 'scale_pos_weight': 1.7678187578626685}. Best is trial 49 with value: 0.27068612029500494.
# [I 2022-01-25 16:06:23,922] Trial 53 finished with value: -0.13536626107033825 and parameters: {'n_estimators': 776, 'max_depth': 7, 'max_delta_step': 0, 'learning_rate': 0.0012626213870999732, 'gamma': 74.89044114071235, 'min_child_weight': 68.18532877306862, 'subsample': 0.9556104285187436, 'colsample_bytree': 0.4981710020871429, 'colsample_bylevel': 0.6745228882565708, 'colsample_bynode': 0.8471332674523138, 'reg_alpha': 0.00018367399766640687, 'reg_lambda': 0.020875813287745237, 'scale_pos_weight': 1.734945088488503}. Best is trial 49 with value: 0.27068612029500494.
# [I 2022-01-25 16:07:03,943] Trial 54 finished with value: 0.22414263530325038 and parameters: {'n_estimators': 658, 'max_depth': 6, 'max_delta_step': 0, 'learning_rate': 0.0043441450647400655, 'gamma': 61.60175118477551, 'min_child_weight': 61.30269000884696, 'subsample': 0.8873667091644686, 'colsample_bytree': 0.5164483899194462, 'colsample_bylevel': 0.5443518378066461, 'colsample_bynode': 0.931763093215818, 'reg_alpha': 7.13182613423776e-05, 'reg_lambda': 0.00301232154145334, 'scale_pos_weight': 1.4367157465788711}. Best is trial 49 with value: 0.27068612029500494.
# [I 2022-01-25 16:07:54,136] Trial 55 finished with value: 0.23723109485158522 and parameters: {'n_estimators': 840, 'max_depth': 11, 'max_delta_step': 0, 'learning_rate': 0.006063942244993122, 'gamma': 54.829488888830674, 'min_child_weight': 81.37416021319352, 'subsample': 0.12553672868966892, 'colsample_bytree': 0.4638716234900849, 'colsample_bylevel': 0.672985531803453, 'colsample_bynode': 0.8664240818319822, 'reg_alpha': 1.976753771286066e-05, 'reg_lambda': 0.018793234283893675, 'scale_pos_weight': 1.3223993663528424}. Best is trial 49 with value: 0.27068612029500494.
# [I 2022-01-25 16:09:31,411] Trial 56 finished with value: 0.16572959017523842 and parameters: {'n_estimators': 798, 'max_depth': 13, 'max_delta_step': 0, 'learning_rate': 0.0027978235962406416, 'gamma': 54.786207978570474, 'min_child_weight': 82.04422058517619, 'subsample': 0.09739507463171732, 'colsample_bytree': 0.458780586244071, 'colsample_bylevel': 0.8077195429247256, 'colsample_bynode': 0.8862894482950575, 'reg_alpha': 2.188149653193085e-05, 'reg_lambda': 0.01720982440417359, 'scale_pos_weight': 1.286683712601848}. Best is trial 49 with value: 0.27068612029500494.
# [I 2022-01-25 16:10:22,609] Trial 57 finished with value: 0.06614453457144635 and parameters: {'n_estimators': 451, 'max_depth': 12, 'max_delta_step': 0, 'learning_rate': 0.003499015489841166, 'gamma': 67.36122989557796, 'min_child_weight': 77.4908499045422, 'subsample': 0.28189584142893453, 'colsample_bytree': 0.3259070496799972, 'colsample_bylevel': 0.6741912971573215, 'colsample_bynode': 0.9601219527192884, 'reg_alpha': 4.48817883054779e-06, 'reg_lambda': 0.07124499677469306, 'scale_pos_weight': 0.8688379356275644}. Best is trial 49 with value: 0.27068612029500494.
# [I 2022-01-25 16:10:57,529] Trial 58 finished with value: 0.2069225117057818 and parameters: {'n_estimators': 649, 'max_depth': 11, 'max_delta_step': 0, 'learning_rate': 0.005471081780006322, 'gamma': 46.1317628378593, 'min_child_weight': 65.54245494061482, 'subsample': 0.06198541231629956, 'colsample_bytree': 0.536698343305978, 'colsample_bylevel': 0.5935500094821125, 'colsample_bynode': 0.8287280602104377, 'reg_alpha': 1.3483355643905189e-05, 'reg_lambda': 0.007432016029049641, 'scale_pos_weight': 1.6524951799616994}. Best is trial 49 with value: 0.27068612029500494.
# [I 2022-01-25 16:12:02,318] Trial 59 finished with value: 0.24092760520034967 and parameters: {'n_estimators': 790, 'max_depth': 9, 'max_delta_step': 0, 'learning_rate': 0.003914047107812109, 'gamma': 74.18400454889381, 'min_child_weight': 89.68683623766084, 'subsample': 0.9943659129937598, 'colsample_bytree': 0.47178794624494613, 'colsample_bylevel': 0.71298318170446, 'colsample_bynode': 0.7007424778928448, 'reg_alpha': 2.6254626052284696e-06, 'reg_lambda': 0.3291671223008117, 'scale_pos_weight': 1.3714847993448958}. Best is trial 49 with value: 0.27068612029500494.
# [I 2022-01-25 16:13:32,631] Trial 60 finished with value: 0.047327532171550876 and parameters: {'n_estimators': 832, 'max_depth': 9, 'max_delta_step': 0, 'learning_rate': 0.0017039192784037043, 'gamma': 57.82519422434924, 'min_child_weight': 90.53572539354576, 'subsample': 0.4106941445826157, 'colsample_bytree': 0.4698559179231002, 'colsample_bylevel': 0.7006056312952225, 'colsample_bynode': 0.7069242777393312, 'reg_alpha': 1.3244802576981782e-06, 'reg_lambda': 0.08941189684680848, 'scale_pos_weight': 1.110655646717641}. Best is trial 49 with value: 0.27068612029500494.
# [I 2022-01-25 16:15:20,051] Trial 61 finished with value: 0.26072832702675797 and parameters: {'n_estimators': 728, 'max_depth': 10, 'max_delta_step': 0, 'learning_rate': 0.004177824030760264, 'gamma': 72.86908046337702, 'min_child_weight': 95.10456303757515, 'subsample': 0.9995569754434602, 'colsample_bytree': 0.5307148563602118, 'colsample_bylevel': 0.7787830271469276, 'colsample_bynode': 0.8704510409812082, 'reg_alpha': 0.00010701362449928646, 'reg_lambda': 0.04157347719549567, 'scale_pos_weight': 1.404743276489094}. Best is trial 49 with value: 0.27068612029500494.
# [I 2022-01-25 16:16:49,104] Trial 62 finished with value: 0.26688853598787715 and parameters: {'n_estimators': 745, 'max_depth': 11, 'max_delta_step': 0, 'learning_rate': 0.004235856512152427, 'gamma': 73.62902808450936, 'min_child_weight': 93.95503159310474, 'subsample': 0.9726981303466486, 'colsample_bytree': 0.5285836322064592, 'colsample_bylevel': 0.7853774991481485, 'colsample_bynode': 0.9248502380645082, 'reg_alpha': 2.816197417751954e-06, 'reg_lambda': 0.032893179943000894, 'scale_pos_weight': 1.193182263767705}. Best is trial 49 with value: 0.27068612029500494.
# [I 2022-01-25 16:18:11,470] Trial 63 finished with value: 0.1711546800856179 and parameters: {'n_estimators': 708, 'max_depth': 10, 'max_delta_step': 0, 'learning_rate': 0.0025883824342659146, 'gamma': 73.83019508318078, 'min_child_weight': 94.2858936620973, 'subsample': 0.9985916289657576, 'colsample_bytree': 0.5224764361170392, 'colsample_bylevel': 0.9276551481598632, 'colsample_bynode': 0.9163461600190747, 'reg_alpha': 3.177236750355271e-06, 'reg_lambda': 0.6289080422520072, 'scale_pos_weight': 1.180359337524832}. Best is trial 49 with value: 0.27068612029500494.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-93-8bb883a25f14> in <module>
# ----> 1 study.optimize(objective, n_trials=100, timeout=5400)
#
# ~/.local/lib/python3.8/site-packages/optuna/study/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     398             )
#     399
# --> 400         _optimize(
#     401             study=self,
#     402             func=func,
#
# ~/.local/lib/python3.8/site-packages/optuna/study/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64     try:
#      65         if n_jobs == 1:
# ---> 66             _optimize_sequential(
#      67                 study,
#      68                 func,
#
# ~/.local/lib/python3.8/site-packages/optuna/study/_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     161
#     162         try:
# --> 163             trial = _run_trial(study, func, catch)
#     164         except Exception:
#     165             raise
#
# ~/.local/lib/python3.8/site-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     211
#     212     try:
# --> 213         value_or_values = func(trial)
#     214     except exceptions.TrialPruned as e:
#     215         # TODO(mamu): Handle multi-objective cases.
#
# <ipython-input-91-231e8ee37944> in objective(trial)
#      40                                    random_state=700)
#      41
# ---> 42         rfr = rfr.fit(X_train, y_train,
#      43                       eval_set=[(X_valid, y_valid)],
#      44                       early_stopping_rounds=10,
#
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     419         for k, arg in zip(sig.parameters, args):
#     420             kwargs[k] = arg
# --> 421         return f(**kwargs)
#     422
#     423     return inner_f
#
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, feature_weights, callbacks)
#     594                 params.update({'eval_metric': eval_metric})
#     595
# --> 596         self._Booster = train(params, train_dmatrix,
#     597                               self.get_num_boosting_rounds(), evals=evals,
#     598                               early_stopping_rounds=early_stopping_rounds,
#
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks)
#     217     Booster : a trained booster model
#     218     """
# --> 219     bst = _train_internal(params, dtrain,
#     220                           num_boost_round=num_boost_round,
#     221                           evals=evals,
#
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks, evals_result, maximize, verbose_eval, early_stopping_rounds)
#     112         # Skip the first update if it is a recovery step.
#     113         if version % 2 == 0:
# --> 114             bst.update(dtrain, i, obj)
#     115             bst.save_rabit_checkpoint()
#     116             version += 1
#
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    1265
#    1266         if fobj is None:
# -> 1267             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1268                                                     ctypes.c_int(iteration),
#    1269                                                     dtrain.handle))
#
# KeyboardInterrupt:

# %%
df = study.trials_dataframe().drop(columns=['number', 'datetime_start', 'datetime_complete', 'duration'])
df
# Out:
#          value  params_colsample_bylevel  params_colsample_bynode  \
# 0   104.459135                  0.935860                 0.098640
# 1   103.754082                  0.058646                 0.385842
# 2   103.918561                  0.393856                 0.176184
# 3    97.897081                  0.810510                 0.973947
# 4   102.952372                  0.983119                 0.168047
# 5   104.033263                  0.214622                 0.942234
# 6    90.485934                  0.865399                 0.121509
# 7    86.782144                  0.356532                 0.035264
# 8   104.606517                  0.782011                 0.439609
# 9   104.596373                  0.681472                 0.263088
# 10   96.709737                  0.516942                 0.765637
# 11   83.284522                  0.449983                 0.004522
# 12   90.527735                  0.423202                 0.004462
# 13   96.783318                  0.258256                 0.596215
# 14   93.642824                  0.584104                 0.007410
# 15  104.232590                  0.244793                 0.288838
# 16   89.651252                  0.366505                 0.564453
# 17  104.560850                  0.017110                 0.285231
# 18   58.668288                  0.622200                 0.740397
# 19   99.055985                  0.631209                 0.701403
# 20   94.759764                  0.736958                 0.810959
# 21   66.738383                  0.481776                 0.649065
# 22   63.823406                  0.499303                 0.642328
#
#     params_colsample_bytree  params_gamma  params_learning_rate  \
# 0                  0.377982     23.858322              0.003134
# 1                  0.384966     68.084300              0.007663
# 2                  0.448321     64.064623              0.000172
# 3                  0.968225     11.214054              0.004709
# 4                  0.164090     93.850167              0.001483
# 5                  0.389488     44.904963              0.000669
# 6                  0.840085     23.100786              0.001843
# 7                  0.547122     21.507110              0.000819
# 8                  0.402621     73.613210              0.000418
# 9                  0.011475      5.921433              0.000109
# 10                 0.685685     39.867762              0.000327
# 11                 0.751695     28.183790              0.001567
# 12                 0.651806     26.146705              0.000968
# 13                 0.608224     33.591834              0.002012
# 14                 0.788905     55.934607              0.000617
# 15                 0.983081     15.009346              0.001050
# 16                 0.560964      2.595984              0.003482
# 17                 0.770243     34.461526              0.000282
# 18                 0.194646     55.107594              0.009221
# 19                 0.220969     83.203718              0.008208
# 20                 0.219665     53.331973              0.005345
# 21                 0.517887     48.153268              0.002497
# 22                 0.026708     49.567245              0.002690
#
#     params_max_delta_step  params_max_depth  params_min_child_weight  \
# 0                       2                18                13.982098
# 1                       1                14                98.158616
# 2                       0                13                63.144352
# 3                       2                17                65.203749
# 4                       2                17                37.600636
# 5                       2                 4                16.182684
# 6                       0                17                59.439288
# 7                       0                 3                33.829321
# 8                       1                 2                39.403250
# 9                       1                13                59.847590
# 10                      0                 6                 0.861789
# 11                      0                 8                82.749794
# 12                      0                 8                89.212385
# 13                      0                 1                82.523722
# 14                      0                 9                39.933766
# 15                      1                 5                77.043781
# 16                      0                 7                24.142130
# 17                      1                11                47.221789
# 18                      0                 3                28.154465
# 19                      1                10                73.547435
# 20                      0                 6                97.690694
# 21                      0                 3                27.931509
# 22                      0                 1                25.668393
#
#     params_n_estimators  params_reg_alpha  params_reg_lambda  \
# 0                    30          0.271786           0.501009
# 1                   138          0.005274           0.000035
# 2                    62          0.002184           0.089606
# 3                   893          0.000201           0.001697
# 4                   691          0.000392           0.000456
# 5                   533          0.000012           0.139531
# 6                   134          0.000002           0.000002
# 7                   401          0.000280           0.742642
# 8                    16          0.050336           0.000007
# 9                   176          0.003526           0.460847
# 10                  373          0.000028           0.004750
# 11                  274          0.000003           0.000002
# 12                  258          0.000002           0.000193
# 13                   64          0.000045           0.008757
# 14                  303          0.000096           0.000044
# 15                  445          0.024397           0.022040
# 16                   75          0.000012           0.000001
# 17                  223          0.000544           0.000018
# 18                  585          0.000001           0.000208
# 19                  845          0.000001           0.000081
# 20                   31          0.000007           0.000008
# 21                  469          0.000005           0.001372
# 22                  572          0.000003           0.001284
#
#     params_scale_pos_weight  params_subsample     state
# 0                  1.150780          0.116786  COMPLETE
# 1                  0.517886          0.381295  COMPLETE
# 2                  1.737881          0.130752  COMPLETE
# 3                  1.025317          0.425041  COMPLETE
# 4                  0.759146          0.013755  COMPLETE
# 5                  0.366087          0.384604  COMPLETE
# 6                  1.270288          0.193466  COMPLETE
# 7                  0.879700          0.996737  COMPLETE
# 8                  0.186831          0.555574  COMPLETE
# 9                  1.679323          0.049155  COMPLETE
# 10                 1.399818          0.946552  COMPLETE
# 11                 1.317331          0.957920  COMPLETE
# 12                 0.743718          0.989217  COMPLETE
# 13                 1.986695          0.794686  COMPLETE
# 14                 0.877789          0.743894  COMPLETE
# 15                 1.442208          0.810799  COMPLETE
# 16                 0.505552          0.672020  COMPLETE
# 17                 0.042824          0.906132  COMPLETE
# 18                 1.074169          0.612034  COMPLETE
# 19                 1.496697          0.611139  COMPLETE
# 20                 1.194940          0.479046  COMPLETE
# 21                 0.979208          0.876167  COMPLETE
# 22                 1.039774          0.863431  COMPLETE

# %%
df.corr()['value'].sort_values()
# Out:
# params_subsample           -0.437734
# params_learning_rate       -0.324363
# params_n_estimators        -0.270546
# params_colsample_bynode    -0.179022
# params_scale_pos_weight    -0.053319
# params_colsample_bylevel   -0.039196
# params_gamma                0.021523
# params_reg_lambda           0.144390
# params_colsample_bytree     0.178293
# params_reg_alpha            0.233974
# params_min_child_weight     0.237860
# params_max_depth            0.482211
# params_max_delta_step       0.568163
# value                       1.000000
# Name: value, dtype: float64

# %%
study.best_params
# Out:
# {'n_estimators': 585,
#  'max_depth': 3,
#  'max_delta_step': 0,
#  'learning_rate': 0.009220710129045235,
#  'gamma': 55.10759374423698,
#  'min_child_weight': 28.15446498358142,
#  'subsample': 0.6120336294212528,
#  'colsample_bytree': 0.19464631486746037,
#  'colsample_bylevel': 0.6222000833075367,
#  'colsample_bynode': 0.7403968045484066,
#  'reg_alpha': 1.2614523422422438e-06,
#  'reg_lambda': 0.00020829275549139398,
#  'scale_pos_weight': 1.074168742869225}
